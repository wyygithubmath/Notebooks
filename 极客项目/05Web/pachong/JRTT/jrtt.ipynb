# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
driver = webdriver.PhantomJS()

# %%
driver.get('http://www.baidu.com/')
driver.implicitly_wait(15)

# %%
bsObj = BeautifulSoup(driver.page_source, "lxml")

# %%
html = requests.get('http://www.toutiao.com/')

# %%
bs = BeautifulSoup(html.text, "lxml")

# %%
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="http://s3.pstatp.com/" rel="dns-prefetch"/>
# <link href="http://s3a.pstatp.com/" rel="dns-prefetch"/>
# <link href="http://s3b.pstatp.com" rel="dns-prefetch"/>
# <link href="http://p1.pstatp.com/" rel="dns-prefetch"/>
# <link href="http://p3.pstatp.com/" rel="dns-prefetch"/>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, minimal-ui" name="viewport"/>
# <meta content="T239HZAbh7" name="baidu-site-verification"/>
# <!--meta name="baidu_union_verify" content="94bb8bb3fa863f70e7fd926bffecd81e"-->
# <meta content="b96e1758dfc9156a410a4fb9520c5956" name="360-site-verification"/>
# <meta content="2ae4ad39552c45425bddb738efda3dbb" name="360_ssp_verify"/>
# <meta content="3PYTTW0s7IAfkReV8wAECfjIdKY-bQeSkVTyJNZpBKE" name="google-site-verification"/>
# <meta content="34c05607e2a9430ad4249ed48faaf7cb_1432711730" name="shenma-site-verification"/>
# <meta content="b88dd3920f970845bad8ad9f90d687f7" name="baidu_union_verify"/>
# <meta content="pmrgi33nmfuw4ir2ej2g65lunfqw6ltdn5wselbcm52wszbchirdqyztge3tenrsgq3dknjume2tayrvmqytemlfmiydimddgu4gcnzcfqrhi2lnmvjwc5tfei5dcnbwhazdcobuhe2dqobrpu" name="domain_verify"/>
# <link href="http://m.toutiao.com/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <title>《今日头条》你关心的,才是头条! - www.toutiao.com</title>
# <meta content="今日头条，头条，头条网，头条新闻，今日头条官网" name="keywords"/>
# <meta content="《今日头条》(www.toutiao.com)是一款基于数据挖掘的推荐引擎产品，它为用户推荐有价值的、个性化的信息，提供连接人与信息的新型服务，是国内移动互联网领域成长最快的产品服务之一。" name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="//s3a.pstatp.com/toutiao/resource/ntoutiao_web/static/image/favicon_8e9c9c7.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//s3a.pstatp.com/toutiao/resource/ntoutiao_web/static/style/lib/layout_9a5b33c.css" rel="stylesheet"/>
# <!--[if lt IE 9]>
#       <script src="//s3a.pstatp.com/toutiao/resource/ntoutiao_web/static/js/lib/es5-shim_110642e.js"></script>
#     <![endif]-->
# <script crossorigin="anonymous" src="//s3.pstatp.com/toutiao/resource/ntoutiao_web/static/js/common/lib_4d986db.js"></script>
# <link href="//s3b.pstatp.com/toutiao/resource/ntoutiao_web/page/home/whome/home_9a322e2.css" rel="stylesheet"/>
# </head>
# <body style="min-width: 1220px; overflow-x: hidden;">
# <div style="display:none"><input name="csrfmiddlewaretoken" type="hidden" value="2236aa49fad359f7bf17c9c2b899fe33"/></div>
# <a href="/articles_news_society/" style="display:none;"></a>
# <div class="y-wrap">
# <!-- 公共头部 -->
# <div id="header">
# <div riot-tag="wtopbar" style="height: 34px; background: #222;"></div>
# </div>
# <div riot-tag="login"></div>
# <div id="toast"></div>
# <div class="y-box container">
# <div class="y-left index-channel">
# <div riot-tag="wchannel"></div>
# </div>
# <div class="y-left index-content">
# <div id="J_carousel" riot-tag="carouselBox" style="height: 300px; margin-bottom: 16px;"></div>
# <div id="subchannel" riot-tag="subchannel"></div>
# <div riot-tag="feedBox"></div>
# </div>
# <div class="y-right index-modules">
# <div id="module-place"></div>
# <div class="module-inner" id="module-inner">
# <div riot-tag="wsearch" style="margin-bottom: 16px;"></div>
# <a class="y-box report" href="http://jubao.12377.cn:13225/reportinputcommon.do" target="_blank">
# <div class="y-left img-holder">
# <img alt="" src="//s3a.pstatp.com/toutiao/resource/ntoutiao_web/static/image/other/report_logo_15cc24e.png"/>
# </div>
# <div class="y-left info">
# <p class="title">网上有害信息举报专区</p>
# <p class="tel">举报电话：12377</p>
# </div>
# </a>
# <div ad-cursor="" class="right-top-1" name="home_right*top_1"></div>
# <div style="height: 366px; overflow:hidden;">
# <div id="m-hotNews">
# <div riot-tag="hotNews"></div>
# <div ad-cursor="" id="adindexhover" name="home_right*bottom_1"></div>
# </div>
# </div>
# <div ad-cursor="" class="right-iframe-ad" name="home_right*top_2"></div>
# <div riot-tag="adTab"></div>
# <div riot-tag="whotvideo"></div>
# <div ad-cursor="" class="right-iframe-ad" name="home_right*top_3"></div>
# <div riot-tag="whotpicture"></div>
# <div class="friendLink module" ga_event="click_friend_link">
# <div class="module-head link-head">友情链接</div>
# <div class="link-content">
# <ul>
# <li class="item"><a href="http://www.gmw.cn/" target="_blank">光明网</a></li>
# <li class="item"><a href="http://www.cnr.cn/" target="_blank">央广网</a></li>
# <li class="item"><a href="http://www.cri.cn" target="_blank">国际在线</a></li>
# <li class="item"><a href="http://www.tibet.cn/" target="_blank">中国西藏网</a></li>
# <li class="item"><a href="http://www.cankaoxiaoxi.com/" target="_blank">参考消息</a></li>
# <li class="item"><a href="http://www.huanqiu.com/" target="_blank">环球网</a></li>
# <li class="item"><a href="http://www.cyol.com" target="_blank">中青在线</a></li>
# <li class="item"><a href="http://www.youth.cn/" target="_blank">中青网</a></li>
# <li class="item"><a href="http://www.haiwainet.cn/" target="_blank">海外网</a></li>
# <li class="item"><a href="http://h5.china.com.cn" target="_blank">中国网</a></li>
# <li class="item"><a href="http://www.k618.cn/" target="_blank">未来网</a></li>
# <li class="item"><a href="http://qianlong.com/" target="_blank">千龙网</a></li>
#     </a>
# <a class="icp" href="/license/" target="_blank">网络文化经营许可证</a>
# </div>
# <p>京-非经营性-2016-0081</p>
# <p>互联网药品信息服务资格证书</p>
# <a href="/a3642705768/" target="_blank">跟帖评论自律管理承诺书 </a>
# <span>违法和不良信息举报：010-58341833</span>
# <span>公司名称：北京字节跳动科技有限公司</span>
# <a ga_event="click_about" href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=11000002002023" target="_blank"><img src="//s3.pstatp.com/toutiao/resource/ntoutiao_web/static/image/gongan_d0289dc.png"/>京公网安备 11000002002023号</a>
# </div>
# </div>
# </div>
# </div>
# <div class="action-feedback">
# <div riot-tag="feedback"></div>
# </div>
# <div riot-tag="verification"></div>
# <div riot-tag="articleLayerBox"></div>
# </div>
# <script>
#
#         if (window.Raven) {
#             Raven.config('http://378ab094b954465fafbe0ac1fa33469e@sentry-server.sentry.m.byted.org/51', {
#                 // whitelistUrls: [/pstatp\.com/]
#             }).install();
#         }
#
#         window.globals = window.globals || {};
#
#         taAnalysis && taAnalysis.setup({
#           c: '/'
#         });
#         taAnalysis && taAnalysis.send('pageview', {});
#
#         var antiPVHandler = utils.on(window, 'scroll', function(e) {
#           taAnalysis && taAnalysis.send('antipageview', {});
#           utils.off(window, 'scroll', antiPVHandler);
#         });
#
#         window.gaqpush = function (ga_action, ga_label){
#             ga('send', 'event','/' , ga_action, ga_label);
#         };
#
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         // ga('create', 'UA-28423340-5', 'auto');
#         ga('create', 'UA-28423340-5', 'auto', {'sampleRate': 10});
#         ga('send', 'pageview');
#
#         utils.on(document.getElementsByTagName('body')[0], 'click', function(e) {
#             var target = utils.getTarget(e),
#                 ga_event,
#                 ga_category,
#                 ga_label,
#                 ga_value;
#
#             while(target && target.nodeName.toUpperCase() !== 'BODY') {
#                 ga_event = utils.getAttribute(target, 'ga_event');
#                 ga_category = utils.getAttribute(target, 'ga_category') || '/';
#                 ga_label = utils.getAttribute(target, 'ga_label');
#                 ga_value = utils.getAttribute(target, 'ga_value') || 1;
#
#                 ga_event && ga('send', 'event', ga_category, ga_event, ga_label, ga_value);
#                 ga_event && taAnalysis && taAnalysis.send('event', { ev: ga_event });
#                 target = target.parentNode;
#             }
#         });
#
#         riot.observable(window);
#     </script>
# <script src="//s3a.pstatp.com/toutiao/resource/ntoutiao_web/page/home/whome/home_d7c455b.js"></script>
# <script type="text/javascript">
#   window.jsblock=function(){
#     setTimeout(function () {
#       _czc && _czc.push(['_trackEvent', 'jsblock', 'home', 'block', 1, ''])
#     }, 1500);
#   }
# </script>
# <script charset="utf-8" onerror="return window.jsblock()" src="//s3.pstatp.com/toutiao/ad_putting/dist/ad.min.js?ver=170315_01"></script>
# <script>
#   // 用户信息
#   var userInfo = {
#       id: 0,
#       name: '',
927\u9646\u6709\u56fd\u6c11\u515a\u201c\u515a\u4ea7\u201d \u5e94\u8be5\u8ba8\u56de"},{"open_url":"\/group\/6404759978738286850\/","group_id":"6404759978738286850","image_url":"http:\/\/p1.pstatp.com\/list\/240x240\/1acb001161b85e357aed","title":"\u82f1\u5a92\uff1a\u5730\u94c1\u7206\u70b8\u65f6\u666e\u4eac\u6216\u6b63\u5728\u5723\u5f7c\u5f97\u5821\u89c6\u5bdf"},{"open_url":"\/group\/6404757641142206978\/","group_id":"6404757641142206978","image_url":"http:\/\/p3.pstatp.com\/list\/240x240\/1a6a000bd44cfdabd197","title":"\u4fc4\u5730\u94c1\u7206\u70b8\u5df2\u9020\u621010\u6b7b50\u4f24 \u666e\u4eac\uff1a\u4e0d\u6392\u9664\u6050\u88ad"},{"open_url":"\/group\/6404626762055975169\/","group_id":"6404626762055975169","image_url":"http:\/\/p1.pstatp.com\/list\/240x240\/1af40000f8b455379bef","title":"\u76f4\u51fb\u96c4\u5b89\u65b0\u533a\u4e28\u96c4\u53bf\uff1a\u672c\u5730\u4eba\u8981\u4ef73\u4e07\u4e00\u5e73\u65b9\u7c73 \u5916\u5730\u5ba2\u62c2\u8896\u800c\u53bb"}]};
#
#   // 二级频道
#   var subchannels = [];
#
#   var hotNews = _data.real_time_news;
#
#   var channelTypeMap = {
#     "essay_joke": 2,
#     "news_image": 3
#   };
#
#   var channelType =  channelTypeMap['__all__'] || 1;
#
#   // ab测试控制
#   var ab_list_style = '0';
#
#   // 推荐效率测试
#   var use_feed_service = true;
#
# </script>
# <script>
#   (function() {
#     var _params = utils.getSearchParams();
#
#     if (_params['ab_list_style']) {
#       ab_list_style = _params['ab_list_style'];
#     }
#   })();
# </script>
# <script>
#   riot.mount('wtopbar', {
#     home: true,
#     userInfo: userInfo,
#     abType: +ab_list_style,
#     pageId: '/'
#   });
# </script>
# <script>
#   riot.mount('carouselBox', {});
#   riot.mount('wsearch', {});
# </script>
# <script>
#   riot.mount('feedBox', {
#     type: channelType,
#     category: '__all__',
#     widen: 1,
#     abType: +ab_list_style,
#     serviceType: use_feed_service
#   });
# </script>
# <script>
#   riot.mount('wchannel', {
#     tag: '__all__' == '__all__'?'/':'/ch/'+'__all__'+'/'
#   });
#   riot.mount('feedback', {
#     abType: +ab_list_style
#   });
#   riot.mount('verification');
#   subchannels && subchannels.length>0 && riot.mount('subchannel', {
#     subchannels: subchannels,
#     suspension: true
#   });
# </script>
# <script>
#   riot.mount('hotNews', {hotNews:hotNews});
#   riot.mount('whotvideo', {});
#   riot.mount('whotpicture', {});
# </script>
# <script language="JavaScript" src="//s95.cnzz.com/z_stat.php?id=1259612802&amp;web_id=1259612802"></script>
# <script src="//s3a.pstatp.com/toutiao/resource/ntoutiao_web/static/js/lib/ua-check_80ba7bd.js"></script>
# </body>
# </html>
