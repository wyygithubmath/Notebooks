# %%
import scipy as sp

# %%
def isPrime(x):
    if x = 1:
        print("A larger number!")
    elif x = 2:
        print()
# Out:
# 7.38905609893065

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10,sp.pi/30)
y = sp.sin(x)

# %%
plt.plot(x, y)
plt.show()
