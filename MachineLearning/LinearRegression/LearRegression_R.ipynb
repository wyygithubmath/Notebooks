# %%
library(ggplot2)

# %%
boson <- read.csv("C:\\Users\\wyy\\Documents\\MATLAB\\boston.csv")

# %%
boson
# Out:
#     X   CRIM     ZN   INDUS CHAS NOX   RM    AGE   DIS    RAD TAX PTRATIO
# 1    1  0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3
# 2    2  0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8
# 3    3  0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8
# 4    4  0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7
# 5    5  0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7
# 6    6  0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7
# 7    7  0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2
# 8    8  0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2
# 9    9  0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2
# 10  10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2
# 11  11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2
# 12  12  0.11747  12.5 7.87  0    0.524 6.009  82.9 6.2267 5   311 15.2
# ...
